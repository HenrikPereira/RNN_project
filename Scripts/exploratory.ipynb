# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
test_df = pd.read_csv(r'../Data/TestDataset.csv')
train_df = pd.read_csv(r'../Data/TrainingDataset.csv')

# %%
test_df.describe()
# Out:
#                id       Cat_1       Date_1        Quan_1       Quan_2  \
# count  519.000000  519.000000   519.000000  5.190000e+02   509.000000
# mean   260.000000    1.439306  2684.369942  1.992936e+06  7092.534381
# std    149.966663    0.496781   571.133688  1.281286e+06  1388.728268
# min      1.000000    1.000000  1414.000000  3.160000e+04  2600.000000
# 25%    130.500000    1.000000  2184.000000  9.227000e+05  6300.000000
# 50%    260.000000    1.000000  2709.000000  1.950700e+06  7300.000000
# 75%    389.500000    2.000000  3199.000000  2.783650e+06  8100.000000
# max    519.000000    2.000000  3682.000000  5.268500e+06  9600.000000
#
#            Quan_3        Quan_4       Date_2      Quan_5      Quan_6  \
# count  518.000000  4.630000e+02   519.000000  182.000000  182.000000
# mean    65.756757  4.257661e+05  2145.302505   27.989011    8.989011
# std     34.382121  5.379712e+05   702.536229   40.120948   12.015179
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Columns: 547 entries, id to Cat_514
# dtypes: float64(25), int64(522)
# memory usage: 2.2 MB

# %%
test_df.nunique()
# Out:
# id         519
# Cat_1        2
# Date_1     259
# Quan_1     124
# Quan_2      66
# Quan_3     136
# Quan_4     391
# Date_2     295
# Quan_5      64
# Quan_6      36
# Quan_7      31
# Quan_8      64
# Quan_9      64
# Quan_10     52
# Quan_11     34
# Quan_12     18
# Quan_13     52
# Quan_14     52
# Cat_2       64
# Cat_3      224
# Cat_4      321
# Cat_5       13
# Cat_6       51
# Cat_7       14
# Cat_8       24
# Cat_9        5
# Cat_10       4
# Cat_11       2
# Cat_12       3
# Cat_13       2
#           ...
# Cat_490      9
# Cat_491      2
# Cat_492      2
# Cat_493      2
# Cat_494      2
# Cat_495      1
# Cat_496      2
# Cat_497      1
# Cat_498      2
# Cat_499      2
# Cat_500      1
# Quan_26      1
# Cat_501      2
# Cat_502      2
# Cat_503      1
# Cat_504      1
# Quan_27      6
# Quan_28      3
# Quan_29      3
# Quan_30      1
# Cat_505      1
# Cat_506      1
# Cat_507      1
# Cat_508      1
# Cat_509      1
# Cat_510      2
# Cat_511      2
# ...

# %%
# Difícil ver aqui alguma cousa...
train_df.describe()
# Out:
#           Outcome_M1     Outcome_M2     Outcome_M3    Outcome_M4  \
# count     751.000000     748.000000     746.000000    746.000000
# mean    20620.505992   10837.566845    5194.369973   3494.638070
# std     54893.895765   26447.885519   10151.524258   6778.269518
# min      2000.000000     500.000000     500.000000    500.000000
# 25%      2000.000000    2000.000000     500.000000    500.000000
# 50%      5000.000000    3000.000000    2000.000000   2000.000000
# 75%     16000.000000    8000.000000    5000.000000   3000.000000
# max    795000.000000  315000.000000  108000.000000  74000.000000
#
#          Outcome_M5    Outcome_M6    Outcome_M7    Outcome_M8    Outcome_M9  \
# count    727.000000    705.000000    694.000000    687.000000    677.000000
# mean    2852.132050   2018.439716   1751.440922   1492.721980   1411.373708
# std     6605.350344   2927.572752   1996.524238   1959.116988   2030.529714
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Columns: 558 entries, Outcome_M1 to Cat_514
# dtypes: float64(37), int64(521)
# memory usage: 3.2 MB

# %%
# São muitas colunas mas ainda dá para perceber que há 4 tipos de dados
train_df.columns.ravel()
# Out:
# array(['Outcome_M1', 'Outcome_M2', 'Outcome_M3', 'Outcome_M4',
#        'Outcome_M5', 'Outcome_M6', 'Outcome_M7', 'Outcome_M8',
#        'Outcome_M9', 'Outcome_M10', 'Outcome_M11', 'Outcome_M12', 'Cat_1',
#        'Date_1', 'Quan_1', 'Quan_2', 'Quan_3', 'Quan_4', 'Date_2',
#        'Quan_5', 'Quan_6', 'Quan_7', 'Quan_8', 'Quan_9', 'Quan_10',
#        'Quan_11', 'Quan_12', 'Quan_13', 'Quan_14', 'Cat_2', 'Cat_3',
#        'Cat_4', 'Cat_5', 'Cat_6', 'Cat_7', 'Cat_8', 'Cat_9', 'Cat_10',
#        'Cat_11', 'Cat_12', 'Cat_13', 'Cat_15', 'Cat_16', 'Quan_15',
#        'Cat_17', 'Cat_18', 'Cat_19', 'Cat_20', 'Cat_21', 'Cat_22',
#        'Cat_23', 'Cat_24', 'Cat_25', 'Cat_26', 'Cat_27', 'Cat_28',
#        'Cat_29', 'Cat_30', 'Cat_31', 'Cat_32', 'Cat_33', 'Cat_34',
#        'Cat_35', 'Cat_36', 'Cat_37', 'Cat_38', 'Cat_39', 'Cat_40',
#        'Cat_41', 'Cat_42', 'Cat_43', 'Cat_44', 'Cat_45', 'Cat_46',
#        'Cat_47', 'Cat_48', 'Cat_49', 'Cat_50', 'Cat_51', 'Cat_52',
# ...

# %%
# agrupar os nomes dos grupos de dados em listas
cat_cols = []
qnt_cols = []
date_cols = []
outc_cols = []
for col in train_df.columns:
    if col.startswith('Cat'):
        cat_cols.append(col)
    elif col.startswith('Quan'):
        qnt_cols.append(col)
    elif col.startswith('Date'):
        date_cols.append(col)
    elif col.startswith('Outcome'):
        outc_cols.append(col)

# %%
train_df[date_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 2 columns):
# Date_1    751 non-null int64
# Date_2    748 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 11.8 KB

# %%
train_df[qnt_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 31 columns):
# Quan_1      751 non-null int64
# Quan_2      739 non-null float64
# Quan_3      746 non-null float64
# Quan_4      672 non-null float64
# Quan_5      277 non-null float64
# Quan_6      277 non-null float64
# Quan_7      277 non-null float64
# Quan_8      277 non-null float64
# Quan_9      277 non-null float64
# Quan_10     277 non-null float64
# Quan_11     277 non-null float64
# Quan_12     277 non-null float64
# Quan_13     277 non-null float64
# Quan_14     277 non-null float64
# Quan_15     740 non-null float64
# Quan_16     443 non-null float64
# Quan_17     424 non-null float64
# Quan_18     70 non-null float64
# Quan_19     187 non-null float64
# Quan_20     44 non-null float64
# Quan_21     111 non-null float64
# Quan_22     16 non-null float64
# Quant_22    72 non-null float64
# Quant_23    84 non-null float64
# Quant_24    344 non-null float64
# ...

# %%
train_df[outc_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 12 columns):
# Outcome_M1     751 non-null int64
# Outcome_M2     748 non-null float64
# Outcome_M3     746 non-null float64
# Outcome_M4     746 non-null float64
# Outcome_M5     727 non-null float64
# Outcome_M6     705 non-null float64
# Outcome_M7     694 non-null float64
# Outcome_M8     687 non-null float64
# Outcome_M9     677 non-null float64
# Outcome_M10    656 non-null float64
# Outcome_M11    645 non-null float64
# Outcome_M12    639 non-null float64
# dtypes: float64(11), int64(1)
# memory usage: 70.5 KB

# %%
train_df[cat_cols].describe()
# Out:
#             Cat_1       Cat_2       Cat_3        Cat_4       Cat_5  \
# count  751.000000  751.000000  751.000000   751.000000  751.000000
# mean     1.447403   30.814913  169.644474   408.561917    4.434088
# std      0.497557   31.130120  164.757195   377.795526    2.733127
# min      1.000000    1.000000    1.000000     1.000000    1.000000
# 25%      1.000000    9.000000   32.000000   123.000000    3.000000
# 50%      1.000000   18.000000  114.000000   287.000000    4.000000
# 75%      2.000000   45.000000  254.000000   586.000000    5.000000
# max      2.000000  236.000000  742.000000  1544.000000   13.000000
#
#             Cat_6       Cat_7       Cat_8       Cat_9      Cat_10      Cat_11  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean    16.985353    1.170439    2.512650    0.123835    0.504660    1.161119
# std     15.756431    3.167372    7.680072    0.957416    1.028743    0.367885
# ...

# %%
sb.boxplot(y=train_df['Date_1'])
plt.show()
sb.boxplot(y=train_df['Date_2'])
plt.show()
sb.boxplot(y=train_df['Date_1']-train_df['Date_2'])
plt.show()
